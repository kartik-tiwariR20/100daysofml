# %%
import numpy as np
from sklearn.datasets import load_diabetes

# %%
x,y = load_diabetes(return_X_y=True)

# %%
x.shape
# Out:
# (442, 10)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2)

# %%
x_train.shape
# Out:
# (353, 10)

# %%
class LinearRegression():

  def __init__(self):
    self.coef_ = None
    self.intercept_ = None


  def fit(self,x_train,y_train):
    x_train = np.insert(x_train,0,1,axis=1)

    betas = np.linalg.inv(np.dot(x_train.T,x_train)).dot(x_train.T).dot(y_train)
    self.intercept_ = betas[0]
    self.coef_ = betas[1:]
    print(self.intercept_)
    print(self.coef_)

  def predict(self,x_test):
    y_pred = self.intercept_ + np.dot(x_test,self.coef_)
    return y_pred

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# 150.79173076307742
# [  -15.58221846  -172.94766864   567.95855155   287.20517845
#  -1134.81907207   667.88288556   307.77513579   255.96890178
#    906.33709203    27.13833838]

# %%
lr.predict(x_test[0])
# Out:
# np.float64(175.829610904604)

# %%
y_test
# Out:
# array([111.,  97., 177., 100.,  59., 110., 182., 151., 129., 273., 140.,
#        241., 190.,  47., 104., 321.,  60., 310., 171., 122., 120., 293.,
#         99., 187.,  51., 174., 158.,  77., 101.,  81.,  80., 168.,  85.,
#        132., 200.,  78., 310.,  99., 164., 172.,  52.,  44.,  48.,  63.,
#         67., 104.,  98., 296., 128., 178., 137., 230., 103.,  53., 346.,
#         55.,  61., 202., 317., 162.,  37.,  85., 219., 259., 248.,  70.,
#        141.,  57.,  71., 214., 134., 150., 280., 174., 248., 297.,  42.,
#        283.,  77., 242.,  96., 168., 200.,  64., 198.,  51., 270., 127.,
#        222.])

# %%
y_pred = lr.predict(x_test)
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.48585773634735163
