# %% [markdown]
# <a href="https://colab.research.google.com/github/kartik-tiwariR20/100daysofml/blob/main/CCAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/data_science_job.csv')
df.sample(10)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 4750         23772   city_28                   0.939   Male
# 11844        26381   city_28                   0.939   Male
# 7250         22203  city_103                   0.920   Male
# 17698         3641  city_103                   0.920   Male
# 15479        26524   city_75                   0.939   Male
# 18870        16045  city_103                   0.920    NaN
# 6398          6646  city_136                   0.897   Male
# 1867         14572   city_21                   0.624   Male
# 11138         1847  city_103                   0.920   Male
# 17569        14036  city_136                   0.897   Male
#
#            relevent_experience enrolled_university education_level  \
# 4750   Has relevent experience       no_enrollment        Graduate
# 11844   No relevent experience       no_enrollment        Graduate
# 7250    No relevent experience    Full time course        Graduate
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %% [markdown]
# 5% se kam jo jo hai usi mai cca lgana chahiye

# %%
df.dropna(subset=['experience'], inplace=True)

# %%
df['experience'].isnull().sum()
# Now, this should show 0 null values for 'experience'
# Out:
# np.int64(0)

# %%
df.dropna(subset=['training_hours'], inplace=True)
df.dropna(subset=['city_development_index'], inplace=True)

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4162
# relevent_experience          0
# enrolled_university        356
# education_level            415
# major_discipline          2621
# experience                   0
# company_size              5534
# company_type              5708
# training_hours               0
# target                       0
# dtype: int64
