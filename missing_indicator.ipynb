# %% [markdown]
# <a href="https://colab.research.google.com/github/kartik-tiwariR20/100daysofml/blob/main/missing_indicator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/train.csv',usecols = ['Age','Fare','Survived'])
df.sample(5)
# Out:
#      Survived   Age   Fare
# 245         0  44.0  90.00
# 564         0   NaN   8.05
# 38          0  18.0  18.00
# 873         0  47.0   9.00
# 298         1   NaN  30.50

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop('Survived',axis=1),df['Survived'],test_size=0.1)

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer()
x_train_trf = si.fit_transform(x_train)
x_test_trf = si.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train_trf,y_train)
y_pred = lr.predict(x_test_trf)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6777777777777778

# %% [markdown]
# SIMPLEIMPUTER MAI HI ADD INDICATOR CLASS HOTI USE TRUE KARDO

# %%
si = SimpleImputer(add_indicator=True)
x_train_trf2 = si.fit_transform(x_train)
x_test_trf2 = si.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train_trf2,y_train)
y_pred2 = lr.predict(x_test_trf2)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred2)
# Out:
# 0.6555555555555556
