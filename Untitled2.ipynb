# %%
import pandas as pd
df = pd.read_csv('/content/Ball_by_Ball.csv')

# %%
df
# Out:
#         Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 0         335987           1        1        1                1
# 1         335987           1        1        2                1
# 2         335987           1        1        3                1
# 3         335987           1        1        4                1
# 4         335987           1        1        5                1
# ...          ...         ...      ...      ...              ...
# 136585    981024           2       20        2                2
# 136586    981024           2       20        3                2
# 136587    981024           2       20        4                2
# 136588    981024           2       20        5                2
# 136589    981024           2       20        6                2
#
#         Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 0                     2           1                         1               2
# ...

# %%
df = pd.read_csv('/content/Ball_by_Ball.csv',index_col='Match_Id')

# %%
df
# Out:
#           Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  Team_Bowling_Id  \
# Match_Id
# 335987             1        1        1                1                2
# 335987             1        1        2                1                2
# 335987             1        1        3                1                2
# 335987             1        1        4                1                2
# 335987             1        1        5                1                2
# ...              ...      ...      ...              ...              ...
# 981024             2       20        2                2               11
# 981024             2       20        3                2               11
# 981024             2       20        4                2               11
# 981024             2       20        5                2               11
# 981024             2       20        6                2               11
#
#           Striker_Id  Striker_Batting_Position  Non_Striker_Id  Bowler_Id  \
# ...

# %%
df = pd.read_csv('/content/Ball_by_Ball.csv',usecols=['Match_Id','Team_Batting_Id','Team_Bowling_Id'])
df
# Out:
#         Match_Id  Team_Batting_Id  Team_Bowling_Id
# 0         335987                1                2
# 1         335987                1                2
# 2         335987                1                2
# 3         335987                1                2
# 4         335987                1                2
# ...          ...              ...              ...
# 136585    981024                2               11
# 136586    981024                2               11
# 136587    981024                2               11
# 136588    981024                2               11
# 136589    981024                2               11
#
# [136590 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136590 entries, 0 to 136589
# Data columns (total 3 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Match_Id         136590 non-null  int64
#  1   Team_Batting_Id  136590 non-null  int64
#  2   Team_Bowling_Id  136590 non-null  int64
# dtypes: int64(3)
# memory usage: 3.1 MB
