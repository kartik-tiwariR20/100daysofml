# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/Social_Network_Ads.csv')
df = df.iloc[:,2:]
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 232   40           107000          1
# 369   54            26000          1
# 121   37            72000          0
# 284   48           141000          0
# 98    35            73000          0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop('Purchased',axis=1),df['Purchased'],test_size=0.2,random_state=0)
x_train.shape,x_test.shape
# Out:
# ((320, 2), (80, 2))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x_train)
x_train_original = x_train.copy()
x_test_original = x_test.copy()
x_train_scaled = sc.transform(x_train)
x_test_scaled = sc.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[ 1.92295008e+00,  2.14601566e+00],
#        [ 2.02016082e+00,  3.78719297e-01],
#        [-1.38221530e+00, -4.32498705e-01],
#        [-1.18779381e+00, -1.01194013e+00],
#        [ 1.92295008e+00, -9.25023920e-01],
#        [ 3.67578135e-01,  2.91803083e-01],
#        [ 1.73156642e-01,  1.46942725e-01],
#        [ 2.02016082e+00,  1.74040666e+00],
#        [ 7.56421121e-01, -8.38107706e-01],
#        [ 2.70367388e-01, -2.87638347e-01],
#        [ 3.67578135e-01, -1.71750061e-01],
#        [-1.18475597e-01,  2.20395980e+00],
#        [-1.47942605e+00, -6.35303205e-01],
#        [-1.28500455e+00, -1.06988428e+00],
#        [-1.38221530e+00,  4.07691369e-01],
#        [-1.09058306e+00,  7.55356227e-01],
#        [-1.47942605e+00, -2.00722133e-01],
#        [ 9.50842613e-01, -1.06988428e+00],
#        [ 9.50842613e-01,  5.81523798e-01],
#        [ 3.67578135e-01,  9.87132798e-01],
#        [ 5.61999628e-01, -8.96051849e-01],
#        [-6.04529329e-01,  1.45068594e+00],
# ...

# %%
feature_columns = df.drop('Purchased', axis=1).columns
x_train_original = pd.DataFrame(x_train_original, columns=feature_columns)
x_test_original = pd.DataFrame(x_test_original, columns=feature_columns)
x_train_scaled = pd.DataFrame(x_train_scaled, columns=feature_columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns=feature_columns)

# %%
print(type(x_train_original))
print(type(x_train_scaled))
print(x_train.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# (320, 2)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(x_train_original['Age'], x_train_original['EstimatedSalary'])
ax1.set_title('Before Scaling')

ax2.scatter(x_train_scaled['Age'], x_train_scaled['EstimatedSalary'], color='red')
ax2.set_title('After Scaling')

plt.show()
