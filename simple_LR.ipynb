# %% [markdown]
# <a href="https://colab.research.google.com/github/kartik-tiwariR20/100daysofml/blob/main/simple_LR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/placementttt.csv')
df.sample(5)
# Out:
#      cgpa  package
# 2    7.82     3.25
# 150  6.30     2.73
# 175  7.04     3.50
# 196  5.89     2.57
# 37   5.90     2.43

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('cgpa')
plt.ylabel('package(in LPA)')
# Out:
# Text(0, 0.5, 'package(in LPA)')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.iloc[:,0:1],df.iloc[:,-1],test_size=0.1,random_state=2)

x_train
# Out:
#      cgpa
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# ..    ...
# 43   7.66
# 22   6.14
# 72   7.78
# 15   7.25
# 168  8.65
#
# [180 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)

from sklearn.metrics import r2_score
r2_score(y_test,lr.predict(x_test))
# Out:
# 0.8510662353930815
