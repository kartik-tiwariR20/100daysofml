# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
x,y = make_regression(n_samples=100,n_features=3,n_informative=3,n_targets=1,noise=42)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import SGDRegressor
sgd = SGDRegressor(penalty = "l2" , max_iter=200,eta0=0.01,alpha=0.001,learning_rate="constant")
sgd.fit(x_train,y_train)
from sklearn.metrics import r2_score
r2_score(y_test,sgd.predict(x_test))
# Out:
# 0.8815863257496976

# %%
from sklearn.linear_model import Ridge
rid = Ridge(alpha=0.001,max_iter=200,solver="sparse_cg")
rid.fit(x_train,y_train)
r2_score(y_test,rid.predict(x_test))
# Out:
# 0.8818950217180734

# %%
class ridgeGD:

  def __init__(self,epochs=200,lr=0.01,alpha=0.001):
    self.intercept_ = None
    self.coef_ = None
    self.epochs = epochs
    self.lr = lr
    self.alpha = alpha

  def fit(self,x_train,y_train):
    self.intercept_ = 0
    self.coef_ = np.ones(x_train.shape[1])
    thetha = np.insert(self.coef_,0,self.intercept_)
    x_train = np.insert(x_train,0,1,axis=1)

    for i in range(self.epochs):
      thetha_der = np.dot(x_train.T,x_train).dot(thetha) - np.dot(x_train.T,y_train)+self.alpha*thetha
      thetha = thetha - (self.lr*thetha_der)

  def predict(self,x_test):
    return self.intercept_ + np.dot(x_test,self.coef_)

# %%
rgd = ridgeGD(lr=0.005)
rgd.fit(x_train,y_train)
r2_score(y_test,rgd.predict(x_test))
# Out:
# -0.2695527228247516
