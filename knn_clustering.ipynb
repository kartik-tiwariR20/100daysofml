# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/student_clustering.csv')
df.shape
# Out:
# (200, 2)

# %%
df.sample(5)
# Out:
#      cgpa   iq
# 148  6.38  107
# 87   5.74  109
# 39   5.57  113
# 70   6.06  109
# 90   8.78  117

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['iq'],color='magenta')

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,10):
  km = KMeans(n_clusters=i)
  km.fit(df)
  wcss.append(km.inertia_)

# %%
plt.plot(range(1,10),wcss)

# %% [markdown]
# pata chal gya best 4 hi hoga

# %%
x = df.iloc[:,:].values
km = KMeans(n_clusters=4)
y = km.fit_predict(x)

# %%
plt.scatter(x[y==0,0],x[y==0,1],color='blue')
plt.scatter(x[y==1,0],x[y==1,1],color='orange')
plt.scatter(x[y==2,0],x[y==2,1],color='aqua')
plt.scatter(x[y==3,0],x[y==3,1],color='red')
